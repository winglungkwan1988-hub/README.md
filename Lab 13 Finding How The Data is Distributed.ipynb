# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding How The Data Is Distributed**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this lab, you will work with a cleaned dataset to perform Exploratory Data Analysis (EDA). You will examine the structure of the data, visualize key variables, and analyze trends related to developer experience, tools, job satisfaction, and other important aspects.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# - Understand the structure of the dataset.
#
# - Perform summary statistics and data visualization.
#
# - Identify trends in developer experience, tools, job satisfaction, and other key variables.

# %% [markdown]
# ### Install the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=9 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.12/site-packages (from seaborn) (2.5.1)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.12/site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=9 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %% [markdown]
# ### Step 1: Import Libraries and Load Data

# %% [markdown]
# - Import the `pandas`, `matplotlib.pyplot`, and `seaborn` libraries.

# %% [markdown]
# - You will begin with loading the dataset. You can use the pyfetch method if working on JupyterLite. Otherwise, you can use pandas' read_csv() function directly on their local machines or cloud environments.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Stack Overflow survey dataset
data_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv'
df = pd.read_csv(data_url)

# Display the first few rows of the dataset
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4  Technical documentation;Blogs;Written Tutorial...  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 2             NaN  Appropriate in length       Easy                 NaN    NaN
# 3             NaN               Too long       Easy                 NaN    NaN
# 4             NaN              Too short       Easy                 NaN    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# ### Step 2: Examine the Structure of the Data

# %% [markdown]
# - Display the column names, data types, and summary information to understand the data structure.
#
# - Objective: Gain insights into the dataset's shape and available variables.

# %%
print(df.columns)
print(df.dtypes)
print(df.info())
df.describe(include="all")
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=114)
# ResponseId               int64
# MainBranch                 str
# Age                        str
# Employment                 str
# RemoteWork                 str
#                         ...
# JobSatPoints_11        float64
# SurveyLength               str
# SurveyEase                 str
# ConvertedCompYearly    float64
# JobSat                 float64
# Length: 114, dtype: object
# <class 'pandas.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), str(100)
# memory usage: 56.9 MB
# None
#           ResponseId                      MainBranch              Age  \
# count   65437.000000                           65437            65437
# unique           NaN                               5                8
# top              NaN  I am a developer by profession  25-34 years old
# freq             NaN                           50207            23911
# mean    32719.000000                             NaN              NaN
# std     18890.179119                             NaN              NaN
# min         1.000000                             NaN              NaN
# 25%     16360.000000                             NaN              NaN
# 50%     32719.000000                             NaN              NaN
# 75%     49078.000000                             NaN              NaN
# max     65437.000000                             NaN              NaN
#
#                  Employment                            RemoteWork   Check  \
# count                 65437                                 54806   65437
# unique                  110                                     3       1
# top     Employed, full-time  Hybrid (some remote, some in-person)  Apples
# freq                  39041                                 23015   65437
# mean                    NaN                                   NaN     NaN
# std                     NaN                                   NaN     NaN
# min                     NaN                                   NaN     NaN
# 25%                     NaN                                   NaN     NaN
# 50%                     NaN                                   NaN     NaN
# 75%                     NaN                                   NaN     NaN
# max                     NaN                                   NaN     NaN
#
#        CodingActivities                                       EdLevel  \
# count             54466                                         60784
# unique              118                                             8
# top               Hobby  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# freq               9993                                         24942
# mean                NaN                                           NaN
# std                 NaN                                           NaN
# min                 NaN                                           NaN
# 25%                 NaN                                           NaN
# 50%                 NaN                                           NaN
# 75%                 NaN                                           NaN
# max                 NaN                                           NaN
#
#                                                 LearnCode  \
# count                                               60488
# unique                                                418
# top     Other online resources (e.g., videos, blogs, f...
# freq                                                 3674
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                           LearnCodeOnline  ... JobSatPoints_6  \
# count                                               49237  ...   29450.000000
# unique                                              10853  ...            NaN
# top     Technical documentation;Blogs;Written Tutorial...  ...            NaN
# freq                                                  603  ...            NaN
# mean                                                  NaN  ...      24.343232
# std                                                   NaN  ...      27.089360
# min                                                   NaN  ...       0.000000
# 25%                                                   NaN  ...       0.000000
# 50%                                                   NaN  ...      20.000000
# 75%                                                   NaN  ...      30.000000
# max                                                   NaN  ...     100.000000
#
#        JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# count     29448.00000   29456.000000   29456.000000    29450.000000
# unique            NaN            NaN            NaN             NaN
# top               NaN            NaN            NaN             NaN
# freq              NaN            NaN            NaN             NaN
# mean         22.96522      20.278165      16.169432       10.955713
# std          27.01774      26.108110      24.845032       22.906263
# min           0.00000       0.000000       0.000000        0.000000
# 25%           0.00000       0.000000       0.000000        0.000000
# 50%          15.00000      10.000000       5.000000        0.000000
# 75%          30.00000      25.000000      20.000000       10.000000
# max         100.00000     100.000000     100.000000      100.000000
#
#        JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly  \
# count     29445.000000                  56182      56238        2.343500e+04
# unique             NaN                      3          3                 NaN
# top                NaN  Appropriate in length       Easy                 NaN
# freq               NaN                  38767      30071                 NaN
# mean          9.953948                    NaN        NaN        8.615529e+04
# std          21.775652                    NaN        NaN        1.867570e+05
# min           0.000000                    NaN        NaN        1.000000e+00
# 25%           0.000000                    NaN        NaN        3.271200e+04
# 50%           0.000000                    NaN        NaN        6.500000e+04
# 75%          10.000000                    NaN        NaN        1.079715e+05
# max         100.000000                    NaN        NaN        1.625660e+07
#
#               JobSat
# count   29126.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        6.935041
# std         2.088259
# min         0.000000
# 25%         6.000000
# 50%         7.000000
# 75%         8.000000
# max        10.000000
#
# [11 rows x 114 columns]

# %% [markdown]
# ### Step 3: Handle Missing Data

# %% [markdown]
# - Identify missing values in the dataset.
#
# - Impute or remove missing values as necessary to ensure data completeness.

# %%
missing_value = df.isnull().sum()
print(missing_value)
missing_percentage = (df.isnull().sum() / len(df)) * 100
print("Missing values percentage:")
print(missing_percentage.round(2))

df = df.drop(columns=["ConvertedCompYearly"])
print(df.isnull().sum())
# Out:
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork                 0
#                        ...
# JobSatPoints_11            0
# SurveyLength               0
# SurveyEase                 0
# ConvertedCompYearly    12725
# JobSat                     0
# Length: 114, dtype: int64
# Missing values percentage:
# ResponseId              0.00
# MainBranch              0.00
# Age                     0.00
# Employment              0.00
# RemoteWork              0.00
#                        ...
# JobSatPoints_11         0.00
# SurveyLength            0.00
# SurveyEase              0.00
# ConvertedCompYearly    44.52
# JobSat                  0.00
# Length: 114, dtype: float64
# ResponseId          0
# MainBranch          0
# Age                 0
# Employment          0
# RemoteWork          0
#                    ..
# JobSatPoints_10    27
# JobSatPoints_11     0
# SurveyLength        0
# SurveyEase          0
# JobSat              0
# Length: 113, dtype: int64

# %% [markdown]
# ### Step 4: Analyze Key Columns

# %% [markdown]
# - Examine key columns such as `Employment`, `JobSat` (Job Satisfaction), and `YearsCodePro` (Professional Coding Experience).
#
# - **Instruction**: Calculate the value counts for each column to understand the distribution of responses.

# %%
print("Employment distribution:")
print(df["Employment"].value_counts())

print("\nJob Satisfaction distribution:")
print(df["JobSat"].value_counts())

print("\nYears of Professional Coding Experience distribution:")
print(df["YearsCodePro"].value_counts())
# Out:
# Employment distribution:
# Employment
# Employed, full-time                                                                                                               22118
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                           2249
# Independent contractor, freelancer, or self-employed                                                                               1219
# Employed, part-time                                                                                                                 522
# Employed, full-time;Student, part-time                                                                                              505
#                                                                                                                                   ...
# Employed, full-time;Not employed, but looking for work;Not employed, and not looking for work;Employed, part-time                     1
# Student, full-time;Not employed, but looking for work;Employed, part-time                                                             1
# Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Retired                                       1
# Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed        1
# Not employed, and not looking for work;Employed, part-time                                                                            1
# Name: count, Length: 63, dtype: int64
#
# Job Satisfaction distribution:
# JobSat
# 8.0     7393
# 7.0     6265
# 6.0     3671
# 9.0     3576
# 10.0    2198
# 5.0     1895
# 3.0     1142
# 4.0     1111
# 2.0      755
# 0.0      303
# 1.0      272
# Name: count, dtype: int64
#
# Years of Professional Coding Experience distribution:
# YearsCodePro
# 3                     2212
# 2                     2103
# 5                     1980
# 10                    1883
# 4                     1830
# 6                     1692
# 8                     1568
# 7                     1517
# 1                     1140
# 12                    1096
# 9                      954
# 15                     918
# 20                     804
# 11                     792
# Less than 1 year       762
# 13                     693
# 14                     612
# 16                     569
# 18                     516
# 25                     493
# 17                     477
# 24                     336
# 30                     315
# 19                     307
# 22                     271
# 23                     254
# 26                     241
# 21                     215
# 27                     207
# 28                     164
# 35                     121
# 32                      97
# 29                      95
# 40                      89
# 34                      72
# 33                      71
# 36                      64
# 31                      53
# 38                      53
# 37                      44
# 45                      30
# 39                      28
# 42                      23
# 41                      21
# 43                      16
# 44                      12
# More than 50 years       8
# 46                       5
# 49                       4
# 48                       3
# 50                       2
# 47                       2
# Name: count, dtype: int64

# %% [markdown]
# ### Step 5: Visualize Job Satisfaction (Focus on JobSat)

# %% [markdown]
# - Create a pie chart or KDE plot to visualize the distribution of `JobSat`.
#
# - Provide an interpretation of the plot, highlighting key trends in job satisfaction.

# %%
job_sat_count = df["JobSat"].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(job_sat_count, labels=job_sat_count.index, autopct="%1.1f%%", startangle=90)
plt.title("Job Satisfaction Distribution")
plt.show()

# %% [markdown]
# ### Step 6: Programming Languages Analysis

# %% [markdown]
# - Compare the frequency of programming languages in `LanguageHaveWorkedWith` and `LanguageWantToWorkWith`.
#
# - Visualize the overlap or differences using a Venn diagram or a grouped bar chart.

# %%
df["LangWorkedList"] = df["LanguageHaveWorkedWith"].str.split(";")
df["LangWantList"] = df["LanguageWantToWorkWith"].str.split(";")
worked = df.explode("LangWorkedList")["LangWorkedList"].str.strip()
want = df.explode("LangWantList")["LangWantList"].str.strip()
worked_counts = worked.value_counts()
want_counts = want.value_counts()

# !pip install matplotlib-venn
from matplotlib_venn import venn2
plt.figure(figsize=(8,6))
venn2(subsets = (set(worked_counts.index), set(want_counts.index)),
    set_labels = ("Languages Worked With", "Languages Want To Work With")
)
plt.title("Overlap of Programming Languages")
plt.show()
# Out:
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-1.1.2.tar.gz (40 kB)
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (from matplotlib-venn) (3.11.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from matplotlib-venn) (2.5.1)
# Collecting scipy (from matplotlib-venn)
#   Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (24.2)
# Requirement already satisfied: pillow>=9 in /opt/conda/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)
# Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 109.3 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: matplotlib-venn
#   Building wheel for matplotlib-venn (pyproject.toml) ... done
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.2-py3-none-any.whl size=45386 sha256=406b5d37023899035a4d6e0c45b900d28f85c418a99726cf53839a113ab083f9
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/c2/47/0c/f014c55a1cfd56dce41a1cafd23e3c590652b5e71330cc181c
# Successfully built matplotlib-venn
# Installing collected packages: scipy, matplotlib-venn
# Successfully installed matplotlib-venn-1.1.2 scipy-1.18.0

# %% [markdown]
# ### Step 7: Analyze Remote Work Trends

# %% [markdown]
# - Visualize the distribution of RemoteWork by region using a grouped bar chart or heatmap.

# %%
cross_tab = pd.crosstab(df["Country"], df["RemoteWork"], normalize="index") * 100
print(cross_tab.round(1))
cross_tab.plot(kind="bar", figsize=(12,6), colormap="Set3")
plt.title("Remote Work Preferences by Region")
plt.xlabel("Country")
plt.ylabel("Percentage (%)")
plt.legend(title="Remote Work Status")
plt.xticks(rotation=45)
plt.show()
# Out:
# RemoteWork                            Hybrid (some remote, some in-person)  \
# Country
# Afghanistan                                                           41.2
# Albania                                                               50.0
# Algeria                                                               35.0
# Andorra                                                                0.0
# Angola                                                                28.6
# ...                                                                    ...
# Venezuela, Bolivarian Republic of...                                   9.4
# Viet Nam                                                              34.9
# Yemen                                                                 33.3
# Zambia                                                                16.7
# Zimbabwe                                                              38.5
#
# RemoteWork                            In-person  Remote
# Country
# Afghanistan                                41.2    17.6
# Albania                                    14.3    35.7
# Algeria                                    20.0    45.0
# Andorra                                    50.0    50.0
# Angola                                     57.1    14.3
# ...                                         ...     ...
# Venezuela, Bolivarian Republic of...       18.8    71.9
# Viet Nam                                   51.2    14.0
# Yemen                                      33.3    33.3
# Zambia                                     50.0    33.3
# Zimbabwe                                   38.5    23.1
#
# [166 rows x 3 columns]

# %% [markdown]
# ### Step 8: Correlation between Job Satisfaction and Experience

# %% [markdown]
# - Analyze the correlation between overall job satisfaction (`JobSat`) and `YearsCodePro`.
#
# - Calculate the Pearson or Spearman correlation coefficient.

# %%
df["YearsCodePro"] = pd.to_numeric(df["YearsCodePro"], errors="coerce")
df["JobSat"] = pd.to_numeric(df["JobSat"], errors="coerce")
pearson_corr = df["YearsCodePro"].corr(df["JobSat"], method="pearson")
print("Pearson correlation:", pearson_corr)
# Out:
# Pearson correlation: 0.10216907367584582

# %% [markdown]
# ### Step 9: Cross-tabulation Analysis (Employment vs. Education Level)

# %% [markdown]
# - Analyze the relationship between employment status (`Employment`) and education level (`EdLevel`).
#
# - **Instruction**: Create a cross-tabulation using `pd.crosstab()` and visualize it with a stacked bar plot if possible.

# %%
cross_tab = pd.crosstab(df["EdLevel"], df["Employment"], normalize="index") * 100
print(cross_tab.round(1))
cross_tab.plot(kind="bar", stacked=True, figsize=(12,6), colormap="Set3")
plt.title("Employment Type Distribution by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Percentage (%)")
plt.legend(title="Employment Type")
plt.xticks(rotation=45)
plt.show()
# Out:
# Employment                                          Employed, full-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                74.7
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                       80.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                    80.0
# Primary/elementary school                                          66.2
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                     81.7
# Secondary school (e.g. American high school, Ge...                 59.2
# Some college/university study without earning a...                 68.6
# Something else                                                     74.1
#
# Employment                                          Employed, full-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                     0.8
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                            0.4
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                         0.4
# Primary/elementary school                                                               0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                          0.4
# Secondary school (e.g. American high school, Ge...                                      0.5
# Some college/university study without earning a...                                      0.4
# Something else                                                                          0.0
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               8.4
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      7.3
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   7.6
# Primary/elementary school                                                                        10.3
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    7.5
# Secondary school (e.g. American high school, Ge...                                                8.5
# Some college/university study without earning a...                                               10.2
# Something else                                                                                   10.3
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.8
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.4
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.4
# Primary/elementary school                                                                         0.7
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.6
# Secondary school (e.g. American high school, Ge...                                                0.3
# Some college/university study without earning a...                                                0.3
# Something else                                                                                    0.4
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         0.7
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.0
# Some college/university study without earning a...                                                0.0
# Something else                                                                                    0.0
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.0
# Some college/university study without earning a...                                                0.0
# Something else                                                                                    0.0
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.6
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.3
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.3
# Primary/elementary school                                                                         0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.2
# Some college/university study without earning a...                                                0.7
# Something else                                                                                    0.4
#
# Employment                                          Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.0
# Some college/university study without earning a...                                                0.1
# Something else                                                                                    0.0
#
# Employment                                          Employed, full-time;Not employed, and not looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.0
# Some college/university study without earning a...                                                0.0
# Something else                                                                                    0.0
#
# Employment                                          Employed, full-time;Not employed, but looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.1
# Primary/elementary school                                                                         0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.1
# Some college/university study without earning a...                                                0.0
# Something else                                                                                    0.0
#
# Employment                                          ...  \
# EdLevel                                             ...
# Associate degree (A.A., A.S., etc.)                 ...
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)        ...
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     ...
# Primary/elementary school                           ...
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)      ...
# Secondary school (e.g. American high school, Ge...  ...
# Some college/university study without earning a...  ...
# Something else                                      ...
#
# Employment                                          Not employed, but looking for work;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.0
# Some college/university study without earning a...                                                0.0
# Something else                                                                                    0.0
#
# Employment                                          Student, full-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                    1.6
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           1.2
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        0.3
# Primary/elementary school                                                              2.2
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         0.1
# Secondary school (e.g. American high school, Ge...                                     7.4
# Some college/university study without earning a...                                     2.8
# Something else                                                                         1.4
#
# Employment                                          Student, full-time;Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.3
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.1
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.1
# Primary/elementary school                                                                         0.7
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.9
# Some college/university study without earning a...                                                0.4
# Something else                                                                                    0.0
#
# Employment                                          Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.2
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.2
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         1.5
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.9
# Some college/university study without earning a...                                                0.3
# Something else                                                                                    0.0
#
# Employment                                          Student, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.0
# Some college/university study without earning a...                                                0.0
# Something else                                                                                    0.0
#
# Employment                                          Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.1
# Some college/university study without earning a...                                                0.0
# Something else                                                                                    0.0
#
# Employment                                          Student, full-time;Not employed, but looking for work;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.0
# Some college/university study without earning a...                                                0.0
# Something else                                                                                    0.0
#
# Employment                                          Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.3
# Some college/university study without earning a...                                                0.0
# Something else                                                                                    0.4
#
# Employment                                          Student, full-time;Student, part-time;Employed, part-time  \
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                               0.0
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                                      0.0
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                                   0.0
# Primary/elementary school                                                                         0.7
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                                    0.0
# Secondary school (e.g. American high school, Ge...                                                0.0
# Some college/university study without earning a...                                                0.0
# Something else                                                                                    0.0
#
# Employment                                          Student, part-time;Employed, part-time
# EdLevel
# Associate degree (A.A., A.S., etc.)                                                    1.1
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                           0.8
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        0.5
# Primary/elementary school                                                              0.0
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         0.1
# Secondary school (e.g. American high school, Ge...                                     3.2
# Some college/university study without earning a...                                     1.3
# Something else                                                                         1.4
#
# [8 rows x 63 columns]

# %% [markdown]
# ### Step 10: Export Cleaned Data

# %% [markdown]
# - Save the cleaned dataset to a new CSV file for further use or sharing.

# %%
df.to_csv("cleaned_dataset.csv", index=False)

print("Cleaned dataset saved as cleaned_dataset.csv"

# %% [markdown]
# ### Summary:

# %% [markdown]
# In this lab, you practiced key skills in exploratory data analysis, including:

# %% [markdown]
# - Examining the structure and content of the Stack Overflow survey dataset to understand its variables and data types.
#
# - Identifying and addressing missing data to ensure the dataset's quality and completeness.
#
# - Summarizing and visualizing key variables such as job satisfaction, programming languages, and remote work trends.
#
# - Analyzing relationships in the data using techniques like:
#     - Comparing programming languages respondents have worked with versus those they want to work with.
#
#     - Exploring remote work preferences by region.
#
# - Investigating correlations between professional coding experience and job satisfaction.
#
# - Performing cross-tabulations to analyze relationships between employment status and education levels.

# %% [markdown]
# ## Authors:
# Ayushi Jain

# %% [markdown]
# ### Other Contributors:
# Rav Ahuja
# Lakshmi Holla
# Malika

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
