# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# Collecting pandas
#   Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 123.6 MB/s eta 0:00:00
# Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 153.9 MB/s eta 0:00:00
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.5.1 pandas-3.0.3
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.25 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 14.3 MB/s eta 0:00:0000:01
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 16.7 MB/s eta 0:00:00:00:01
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.8 MB/s eta 0:00:00
# Downloading pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 17.6 MB/s eta 0:00:00:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pillow-12.3.0 pyparsing-3.3.2

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4  Technical documentation;Blogs;Written Tutorial...  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 2             NaN  Appropriate in length       Easy                 NaN    NaN
# 3             NaN               Too long       Easy                 NaN    NaN
# 4             NaN              Too short       Easy                 NaN    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
duplicates = df.duplicated()

num_duplicates = duplicates.sum()
print("Number of duplicate rows:", num_duplicates)

duplicate_rows = df[df.duplicated()].head()
print(duplicate_rows)
# Out:
# Number of duplicate rows: 0
# Empty DataFrame
# Columns: [ResponseId, MainBranch, Age, Employment, RemoteWork, Check, CodingActivities, EdLevel, LearnCode, LearnCodeOnline, TechDoc, YearsCode, YearsCodePro, DevType, OrgSize, PurchaseInfluence, BuyNewTool, BuildvsBuy, TechEndorse, Country, Currency, CompTotal, LanguageHaveWorkedWith, LanguageWantToWorkWith, LanguageAdmired, DatabaseHaveWorkedWith, DatabaseWantToWorkWith, DatabaseAdmired, PlatformHaveWorkedWith, PlatformWantToWorkWith, PlatformAdmired, WebframeHaveWorkedWith, WebframeWantToWorkWith, WebframeAdmired, EmbeddedHaveWorkedWith, EmbeddedWantToWorkWith, EmbeddedAdmired, MiscTechHaveWorkedWith, MiscTechWantToWorkWith, MiscTechAdmired, ToolsTechHaveWorkedWith, ToolsTechWantToWorkWith, ToolsTechAdmired, NEWCollabToolsHaveWorkedWith, NEWCollabToolsWantToWorkWith, NEWCollabToolsAdmired, OpSysPersonal use, OpSysProfessional use, OfficeStackAsyncHaveWorkedWith, OfficeStackAsyncWantToWorkWith, OfficeStackAsyncAdmired, OfficeStackSyncHaveWorkedWith, OfficeStackSyncWantToWorkWith, OfficeStackSyncAdmired, AISearchDevHaveWorkedWith, AISearchDevWantToWorkWith, AISearchDevAdmired, NEWSOSites, SOVisitFreq, SOAccount, SOPartFreq, SOHow, SOComm, AISelect, AISent, AIBen, AIAcc, AIComplex, AIToolCurrently Using, AIToolInterested in Using, AIToolNot interested in Using, AINextMuch more integrated, AINextNo change, AINextMore integrated, AINextLess integrated, AINextMuch less integrated, AIThreat, AIEthics, AIChallenges, TBranch, ICorPM, WorkExp, Knowledge_1, Knowledge_2, Knowledge_3, Knowledge_4, Knowledge_5, Knowledge_6, Knowledge_7, Knowledge_8, Knowledge_9, Frequency_1, Frequency_2, Frequency_3, TimeSearching, TimeAnswering, Frustration, ProfessionalTech, ProfessionalCloud, ProfessionalQuestion, ...]
# Index: []
#
# [0 rows x 114 columns]

# %% [markdown]
# ### Task 2: Analysis of Duplicate Response Patterns
# 1. Identify duplicate response patterns based on selected columns such as MainBranch, Employment, and RemoteWork.
# 2. Clarify that these represent multiple respondents with identical answers rather than duplicate records. Analyse which other columns frequently share identical values within these response-pattern groups.

# %%
grouped = df.groupby(['MainBranch', 'Employment', 'RemoteWork'])
patterns = grouped.size().reset_index(name="count")
duplicate_pattern = patterns[patterns["count"] > 1]
print("duplicate response patterns:")
print(duplicate_pattern)

for _, row in duplicate_pattern.iterrows():
    subset = df[
    (df['MainBranch'] == row['MainBranch']) &
    (df['Employment'] == row['Employment']) &
    (df['RemoteWork'] == row['RemoteWork'])
    ]
    print("\nPattern:", row['MainBranch'], row['Employment'], row['RemoteWork'])
    print("Count:", row["count"])

for col in ['Age', 'LanguageHaveWorkedWith', 'LearnCode']:
    print(f"{col} mode:", subset[col].mode().tolist())
# Out:
# duplicate response patterns:
#                                             MainBranch  \
# 0                       I am a developer by profession
# 1                       I am a developer by profession
# 2                       I am a developer by profession
# 3                       I am a developer by profession
# 4                       I am a developer by profession
# ..                                                 ...
# 438  I used to be a developer by profession, but no...
# 442  I used to be a developer by profession, but no...
# 443  I used to be a developer by profession, but no...
# 444  I used to be a developer by profession, but no...
# 448  I used to be a developer by profession, but no...
#
#                                             Employment  \
# 0                                  Employed, full-time
# 1                                  Employed, full-time
# 2                                  Employed, full-time
# 3              Employed, full-time;Employed, part-time
# 4              Employed, full-time;Employed, part-time
# ..                                                 ...
# 438  Not employed, but looking for work;Independent...
# 442             Student, full-time;Employed, part-time
# 443             Student, full-time;Employed, part-time
# 444             Student, full-time;Employed, part-time
# 448             Student, part-time;Employed, part-time
#
#                                RemoteWork  count
# 0    Hybrid (some remote, some in-person)  15286
# 1                               In-person   7118
# 2                                  Remote  12191
# 3    Hybrid (some remote, some in-person)     78
# 4                               In-person     25
# ..                                    ...    ...
# 438                                Remote      7
# 442  Hybrid (some remote, some in-person)      2
# 443                             In-person      3
# 444                                Remote      2
# 448  Hybrid (some remote, some in-person)      2
#
# [319 rows x 4 columns]
#
# Pattern: I am a developer by profession Employed, full-time Hybrid (some remote, some in-person)
# Count: 15286
#
# Pattern: I am a developer by profession Employed, full-time In-person
# Count: 7118
#
# Pattern: I am a developer by profession Employed, full-time Remote
# Count: 12191
#
# Pattern: I am a developer by profession Employed, full-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 78
#
# Pattern: I am a developer by profession Employed, full-time;Employed, part-time In-person
# Count: 25
#
# Pattern: I am a developer by profession Employed, full-time;Employed, part-time Remote
# Count: 87
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 1168
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 317
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 1754
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 71
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time In-person
# Count: 14
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 81
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work In-person
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 51
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time In-person
# Count: 15
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 53
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 6
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time In-person
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time Remote
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Not employed, but looking for work Hybrid (some remote, some in-person)
# Count: 15
#
# Pattern: I am a developer by profession Employed, full-time;Not employed, but looking for work In-person
# Count: 12
#
# Pattern: I am a developer by profession Employed, full-time;Not employed, but looking for work Remote
# Count: 21
#
# Pattern: I am a developer by profession Employed, full-time;Not employed, but looking for work;Employed, part-time Remote
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 5
#
# Pattern: I am a developer by profession Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed Remote
# Count: 4
#
# Pattern: I am a developer by profession Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 3
#
# Pattern: I am a developer by profession Employed, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Employed, part-time Remote
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Retired Remote
# Count: 3
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time Hybrid (some remote, some in-person)
# Count: 303
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time In-person
# Count: 208
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time Remote
# Count: 185
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 16
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Employed, part-time In-person
# Count: 9
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Employed, part-time Remote
# Count: 5
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 34
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 9
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 37
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 5
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Student, part-time;Employed, part-time;Retired Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Student, part-time;Employed, part-time;Retired In-person
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Student, part-time;Employed, part-time;Retired Remote
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Student, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I am a developer by profession Employed, full-time;Student, full-time;Student, part-time;Employed, part-time In-person
# Count: 2
#
# Pattern: I am a developer by profession Employed, full-time;Student, part-time Hybrid (some remote, some in-person)
# Count: 288
#
# Pattern: I am a developer by profession Employed, full-time;Student, part-time In-person
# Count: 182
#
# Pattern: I am a developer by profession Employed, full-time;Student, part-time Remote
# Count: 213
#
# Pattern: I am a developer by profession Employed, full-time;Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 4
#
# Pattern: I am a developer by profession Employed, full-time;Student, part-time;Employed, part-time Remote
# Count: 4
#
# Pattern: I am a developer by profession Employed, part-time Hybrid (some remote, some in-person)
# Count: 438
#
# Pattern: I am a developer by profession Employed, part-time In-person
# Count: 187
#
# Pattern: I am a developer by profession Employed, part-time Remote
# Count: 293
#
# Pattern: I am a developer by profession Employed, part-time;Retired Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 990
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed In-person
# Count: 211
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed Remote
# Count: 2814
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 153
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Employed, part-time In-person
# Count: 25
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 153
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Employed, part-time;Retired Remote
# Count: 2
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Hybrid (some remote, some in-person)
# Count: 5
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Remote
# Count: 26
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Retired Remote
# Count: 4
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Student, part-time Remote
# Count: 2
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Retired Hybrid (some remote, some in-person)
# Count: 5
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Retired In-person
# Count: 2
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Retired Remote
# Count: 19
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 17
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Student, part-time In-person
# Count: 4
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 56
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 28
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time In-person
# Count: 7
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time Remote
# Count: 18
#
# Pattern: I am a developer by profession Independent contractor, freelancer, or self-employed;Student, part-time;Retired Remote
# Count: 2
#
# Pattern: I am a developer by profession Not employed, but looking for work;Employed, part-time Hybrid (some remote, some in-person)
# Count: 4
#
# Pattern: I am a developer by profession Not employed, but looking for work;Employed, part-time In-person
# Count: 3
#
# Pattern: I am a developer by profession Not employed, but looking for work;Employed, part-time Remote
# Count: 8
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 53
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed In-person
# Count: 13
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed Remote
# Count: 208
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 6
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 11
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Remote
# Count: 3
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Retired Remote
# Count: 3
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 8
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time In-person
# Count: 4
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 13
#
# Pattern: I am a developer by profession Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time Remote
# Count: 3
#
# Pattern: I am a developer by profession Not employed, but looking for work;Student, part-time;Employed, part-time In-person
# Count: 2
#
# Pattern: I am a developer by profession Not employed, but looking for work;Student, part-time;Employed, part-time Remote
# Count: 2
#
# Pattern: I am a developer by profession Student, full-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 359
#
# Pattern: I am a developer by profession Student, full-time;Employed, part-time In-person
# Count: 174
#
# Pattern: I am a developer by profession Student, full-time;Employed, part-time Remote
# Count: 173
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 65
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 15
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 127
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 39
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time In-person
# Count: 4
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 38
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Remote
# Count: 3
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 3
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 4
#
# Pattern: I am a developer by profession Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time Remote
# Count: 4
#
# Pattern: I am a developer by profession Student, full-time;Not employed, but looking for work;Employed, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am a developer by profession Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 13
#
# Pattern: I am a developer by profession Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed Remote
# Count: 23
#
# Pattern: I am a developer by profession Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 3
#
# Pattern: I am a developer by profession Student, full-time;Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am a developer by profession Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 220
#
# Pattern: I am a developer by profession Student, part-time;Employed, part-time In-person
# Count: 120
#
# Pattern: I am a developer by profession Student, part-time;Employed, part-time Remote
# Count: 78
#
# Pattern: I am learning to code Employed, full-time Hybrid (some remote, some in-person)
# Count: 77
#
# Pattern: I am learning to code Employed, full-time In-person
# Count: 182
#
# Pattern: I am learning to code Employed, full-time Remote
# Count: 62
#
# Pattern: I am learning to code Employed, full-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am learning to code Employed, full-time;Employed, part-time In-person
# Count: 3
#
# Pattern: I am learning to code Employed, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 7
#
# Pattern: I am learning to code Employed, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 2
#
# Pattern: I am learning to code Employed, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 7
#
# Pattern: I am learning to code Employed, full-time;Student, full-time Hybrid (some remote, some in-person)
# Count: 14
#
# Pattern: I am learning to code Employed, full-time;Student, full-time In-person
# Count: 21
#
# Pattern: I am learning to code Employed, full-time;Student, full-time Remote
# Count: 4
#
# Pattern: I am learning to code Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 3
#
# Pattern: I am learning to code Employed, full-time;Student, part-time Hybrid (some remote, some in-person)
# Count: 6
#
# Pattern: I am learning to code Employed, full-time;Student, part-time In-person
# Count: 19
#
# Pattern: I am learning to code Employed, full-time;Student, part-time Remote
# Count: 4
#
# Pattern: I am learning to code Employed, part-time Hybrid (some remote, some in-person)
# Count: 25
#
# Pattern: I am learning to code Employed, part-time In-person
# Count: 37
#
# Pattern: I am learning to code Employed, part-time Remote
# Count: 16
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 50
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed In-person
# Count: 28
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed Remote
# Count: 59
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 4
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Remote
# Count: 3
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed;Retired In-person
# Count: 2
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed;Retired Remote
# Count: 3
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 7
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed;Student, part-time In-person
# Count: 6
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 8
#
# Pattern: I am learning to code Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am learning to code Not employed, but looking for work;Employed, part-time In-person
# Count: 2
#
# Pattern: I am learning to code Not employed, but looking for work;Employed, part-time Remote
# Count: 2
#
# Pattern: I am learning to code Not employed, but looking for work;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 11
#
# Pattern: I am learning to code Not employed, but looking for work;Independent contractor, freelancer, or self-employed In-person
# Count: 6
#
# Pattern: I am learning to code Not employed, but looking for work;Independent contractor, freelancer, or self-employed Remote
# Count: 18
#
# Pattern: I am learning to code Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 2
#
# Pattern: I am learning to code Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 4
#
# Pattern: I am learning to code Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 3
#
# Pattern: I am learning to code Not employed, but looking for work;Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am learning to code Student, full-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 33
#
# Pattern: I am learning to code Student, full-time;Employed, part-time In-person
# Count: 61
#
# Pattern: I am learning to code Student, full-time;Employed, part-time Remote
# Count: 17
#
# Pattern: I am learning to code Student, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 10
#
# Pattern: I am learning to code Student, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 10
#
# Pattern: I am learning to code Student, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 26
#
# Pattern: I am learning to code Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 6
#
# Pattern: I am learning to code Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time In-person
# Count: 2
#
# Pattern: I am learning to code Student, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work In-person
# Count: 2
#
# Pattern: I am learning to code Student, full-time;Not employed, but looking for work;Employed, part-time In-person
# Count: 2
#
# Pattern: I am learning to code Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 8
#
# Pattern: I am learning to code Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed In-person
# Count: 6
#
# Pattern: I am learning to code Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed Remote
# Count: 7
#
# Pattern: I am learning to code Student, full-time;Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am learning to code Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 13
#
# Pattern: I am learning to code Student, part-time;Employed, part-time In-person
# Count: 15
#
# Pattern: I am learning to code Student, part-time;Employed, part-time Remote
# Count: 8
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time Hybrid (some remote, some in-person)
# Count: 1479
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time In-person
# Count: 916
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time Remote
# Count: 693
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 5
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Employed, part-time In-person
# Count: 3
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Employed, part-time Remote
# Count: 6
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 121
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 33
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 77
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 6
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time In-person
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 5
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 7
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time In-person
# Count: 5
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 5
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Retired Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, full-time Hybrid (some remote, some in-person)
# Count: 63
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, full-time In-person
# Count: 65
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, full-time Remote
# Count: 16
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, full-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 4
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, full-time;Employed, part-time In-person
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Student, part-time;Employed, part-time;Retired Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, part-time Hybrid (some remote, some in-person)
# Count: 40
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, part-time In-person
# Count: 41
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, full-time;Student, part-time Remote
# Count: 21
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, part-time Hybrid (some remote, some in-person)
# Count: 89
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, part-time In-person
# Count: 47
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, part-time Remote
# Count: 37
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Employed, part-time;Retired Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 164
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed In-person
# Count: 33
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed Remote
# Count: 224
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 26
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Employed, part-time In-person
# Count: 5
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 10
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Employed, part-time;Retired Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Retired Remote
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Retired Hybrid (some remote, some in-person)
# Count: 5
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 7
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 8
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time Remote
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Not employed, and not looking for work;Employed, part-time Remote
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Not employed, but looking for work;Employed, part-time Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Not employed, but looking for work;Employed, part-time In-person
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Not employed, but looking for work;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 12
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Not employed, but looking for work;Independent contractor, freelancer, or self-employed In-person
# Count: 4
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Not employed, but looking for work;Independent contractor, freelancer, or self-employed Remote
# Count: 22
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 4
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, full-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 102
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, full-time;Employed, part-time In-person
# Count: 77
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, full-time;Employed, part-time Remote
# Count: 35
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 29
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 4
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 23
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 16
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 6
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 8
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed Remote
# Count: 6
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 46
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, part-time;Employed, part-time In-person
# Count: 36
#
# Pattern: I am not primarily a developer, but I write code sometimes as part of my work/studies Student, part-time;Employed, part-time Remote
# Count: 7
#
# Pattern: I code primarily as a hobby Employed, full-time Hybrid (some remote, some in-person)
# Count: 97
#
# Pattern: I code primarily as a hobby Employed, full-time In-person
# Count: 185
#
# Pattern: I code primarily as a hobby Employed, full-time Remote
# Count: 48
#
# Pattern: I code primarily as a hobby Employed, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 8
#
# Pattern: I code primarily as a hobby Employed, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 7
#
# Pattern: I code primarily as a hobby Employed, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 5
#
# Pattern: I code primarily as a hobby Employed, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Employed, part-time Remote
# Count: 2
#
# Pattern: I code primarily as a hobby Employed, full-time;Retired In-person
# Count: 2
#
# Pattern: I code primarily as a hobby Employed, full-time;Student, full-time Hybrid (some remote, some in-person)
# Count: 5
#
# Pattern: I code primarily as a hobby Employed, full-time;Student, full-time In-person
# Count: 8
#
# Pattern: I code primarily as a hobby Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Student, part-time;Employed, part-time;Retired Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I code primarily as a hobby Employed, full-time;Student, part-time Hybrid (some remote, some in-person)
# Count: 4
#
# Pattern: I code primarily as a hobby Employed, full-time;Student, part-time In-person
# Count: 6
#
# Pattern: I code primarily as a hobby Employed, full-time;Student, part-time Remote
# Count: 2
#
# Pattern: I code primarily as a hobby Employed, part-time Hybrid (some remote, some in-person)
# Count: 15
#
# Pattern: I code primarily as a hobby Employed, part-time In-person
# Count: 43
#
# Pattern: I code primarily as a hobby Employed, part-time Remote
# Count: 8
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 48
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed In-person
# Count: 27
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed Remote
# Count: 63
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 4
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 2
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Remote
# Count: 10
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 4
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed;Student, part-time In-person
# Count: 2
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 6
#
# Pattern: I code primarily as a hobby Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time In-person
# Count: 2
#
# Pattern: I code primarily as a hobby Not employed, but looking for work;Employed, part-time In-person
# Count: 2
#
# Pattern: I code primarily as a hobby Not employed, but looking for work;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 9
#
# Pattern: I code primarily as a hobby Not employed, but looking for work;Independent contractor, freelancer, or self-employed Remote
# Count: 10
#
# Pattern: I code primarily as a hobby Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I code primarily as a hobby Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 4
#
# Pattern: I code primarily as a hobby Student, full-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 20
#
# Pattern: I code primarily as a hobby Student, full-time;Employed, part-time In-person
# Count: 42
#
# Pattern: I code primarily as a hobby Student, full-time;Employed, part-time Remote
# Count: 14
#
# Pattern: I code primarily as a hobby Student, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 13
#
# Pattern: I code primarily as a hobby Student, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 7
#
# Pattern: I code primarily as a hobby Student, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 41
#
# Pattern: I code primarily as a hobby Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I code primarily as a hobby Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time In-person
# Count: 3
#
# Pattern: I code primarily as a hobby Student, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 4
#
# Pattern: I code primarily as a hobby Student, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work In-person
# Count: 3
#
# Pattern: I code primarily as a hobby Student, full-time;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Remote
# Count: 4
#
# Pattern: I code primarily as a hobby Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 5
#
# Pattern: I code primarily as a hobby Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I code primarily as a hobby Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed Remote
# Count: 10
#
# Pattern: I code primarily as a hobby Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 2
#
# Pattern: I code primarily as a hobby Student, part-time;Employed, part-time In-person
# Count: 8
#
# Pattern: I code primarily as a hobby Student, part-time;Employed, part-time Remote
# Count: 4
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time Hybrid (some remote, some in-person)
# Count: 342
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time In-person
# Count: 151
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time Remote
# Count: 199
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 26
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Independent contractor, freelancer, or self-employed In-person
# Count: 7
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Independent contractor, freelancer, or self-employed Remote
# Count: 18
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Not employed, but looking for work Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Retired In-person
# Count: 2
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Student, full-time In-person
# Count: 3
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Student, part-time Hybrid (some remote, some in-person)
# Count: 4
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Student, part-time In-person
# Count: 5
#
# Pattern: I used to be a developer by profession, but no longer am Employed, full-time;Student, part-time Remote
# Count: 4
#
# Pattern: I used to be a developer by profession, but no longer am Employed, part-time Hybrid (some remote, some in-person)
# Count: 7
#
# Pattern: I used to be a developer by profession, but no longer am Employed, part-time In-person
# Count: 16
#
# Pattern: I used to be a developer by profession, but no longer am Employed, part-time Remote
# Count: 6
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 44
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed In-person
# Count: 14
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed Remote
# Count: 70
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed;Employed, part-time Hybrid (some remote, some in-person)
# Count: 5
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed;Employed, part-time In-person
# Count: 4
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed;Employed, part-time Remote
# Count: 6
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed;Not employed, and not looking for work Remote
# Count: 3
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed;Retired Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed;Retired Remote
# Count: 8
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed;Student, part-time Hybrid (some remote, some in-person)
# Count: 3
#
# Pattern: I used to be a developer by profession, but no longer am Independent contractor, freelancer, or self-employed;Student, part-time Remote
# Count: 2
#
# Pattern: I used to be a developer by profession, but no longer am Not employed, but looking for work;Independent contractor, freelancer, or self-employed Hybrid (some remote, some in-person)
# Count: 5
#
# Pattern: I used to be a developer by profession, but no longer am Not employed, but looking for work;Independent contractor, freelancer, or self-employed Remote
# Count: 7
#
# Pattern: I used to be a developer by profession, but no longer am Student, full-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 2
#
# Pattern: I used to be a developer by profession, but no longer am Student, full-time;Employed, part-time In-person
# Count: 3
#
# Pattern: I used to be a developer by profession, but no longer am Student, full-time;Employed, part-time Remote
# Count: 2
#
# Pattern: I used to be a developer by profession, but no longer am Student, part-time;Employed, part-time Hybrid (some remote, some in-person)
# Count: 2
# Age mode: ['25-34 years old']
# LanguageHaveWorkedWith mode: ['Bash/Shell (all shells);HTML/CSS;JavaScript;Python;R;SQL', 'Bash/Shell (all shells);Julia;Python;R;Rust;SQL']
# LearnCode mode: ['Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification', 'Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community)']

# %% [markdown]
# ### Task 3: Visualize Shared Response Patterns
# 1. Create visualizations to show the distribution of shared response patterns across different categories.
# 2. Use bar charts or pie charts to represent the distribution of respondents who share identical values for MainBranch, Employment, and RemoteWork, grouped by Country and Employment.

# %%
import plotly.express as px
pattern_data = (
    df.groupby(["MainBranch", "Employment", "RemoteWork", "Country"])
      .size()
      .to_frame("count")
      .reset_index()
)

share_data = pattern_data[pattern_data["count"] > 1]

fig = px.pie(
    share_data,
    names="Country",
    values="count",
    color="Employment",
    title="Shared Response Patterns Distribution"
)
fig.update_layout(
    width=1000,
    height=1000
)
fig.show()

# %% [markdown]
# ### Task 4: Evaluate Duplicate Handling Strategy
# 1. Analyse the dataset to determine which column(s) define record uniqueness.
# 2. Assess whether removing rows based on a subset of columns (rather than complete row duplication) is appropriate.
# Justify your decision with reference to the structure and purpose of the dataset.

# %% [raw]
# 欄位重複太多, 一些描述相似的欄位刪除可能比較好

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %% [raw]
# LearnCodeOnline, YearsCodePro, LanguageWantToWorkWith, LanguageAdmired, DatabaseHaveWorkedWith, DatabaseWantToWorkWith, DatabaseAdmired, PlatformHaveWorkedWith, PlatformWantToWorkWith, PlatformAdmired, WebframeHaveWorkedWith, WebframeWantToWorkWith, WebframeAdmired, EmbeddedHaveWorkedWith, EmbeddedWantToWorkWith, EmbeddedAdmired, MiscTechHaveWorkedWith, MiscTechWantToWorkWith, MiscTechAdmired, ToolsTechHaveWorkedWith, ToolsTechWantToWorkWith, ToolsTechAdmired, NEWCollabToolsHaveWorkedWith, NEWCollabToolsWantToWorkWith, NEWCollabToolsAdmired, OfficeStackAsyncHaveWorkedWith, OfficeStackAsyncWantToWorkWith, OfficeStackAsyncAdmired, OfficeStackSyncHaveWorkedWith, OfficeStackSyncWantToWorkWith, OfficeStackSyncAdmired, AISearchDevHaveWorkedWith, AISearchDevWantToWorkWith, AISearchDevAdmired, NEWSOSites, SOVisitFreq, SOAccount, SOPartFreq, SOHow, SOComm, AISelect, AISent, AIBen, AIAcc, AIComplex, AIToolInterested in Using, AIToolNot interested in Using, AINextMuch more integrated, AINextNo change, AINextMore integrated, AINextLess integrated, AINextMuch less integrated, AIThreat, AIEthics, AIChallenges, TBranch, ICorPM, WorkExp, Knowledge_1, Knowledge_2, Knowledge_3, Knowledge_4, Knowledge_5, Knowledge_6, Knowledge_7, Knowledge_8, Knowledge_9, Frequency_1, Frequency_2, Frequency_3, ProfessionalTech, ProfessionalCloud, ProfessionalQuestion

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# 這些欄位可能與問題不符, 分類太多

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
